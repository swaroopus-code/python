# %%
n = 5
for i in range(n):
    for j in range(n):
        print("*",end = " ")
    print()
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
n = int(input("enter the rows : "))
for i in range(n):
    for j in range(0, i+1): #column
        print("*", end = " ")
    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
n = int (input("enter the rows: "))
for i in range(n):
    for j in range(i,n): #range(0, 5) - 5 stars then (1,4) - 4 stars..
        print("*", end =" ")
    print()
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
n = 5
for i in range(n):
    for j in range(i,n):
        print(" ",end = " ")
    for k in range(i+1):
        print("*",end = " ")
    print()
# Out:
#           *
#         * *
#       * * *
#     * * * *
#   * * * * *

# %%
n = 5
for i in range(n):
    for j in range(1,i+1):
            print(" ",end = " ")
    for k in range(i,n):
        print("*",end = " ")
    print()
# Out:
# * * * * *
#   * * * *
#     * * *
#       * *
#         *

# %%
n = 5
for i in range(n):
    for j in range(i,n-1): 
        print(" ", end = ' ')
    for k in range(i+1):
        print("*",end = " ")
    for l in range(1,i+1):
        print("*", end = " ")
    print()
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *

# %%
n = 5
for i in range(n):
    for j in range(0,i+1):
        print(" ",end = " ")
    for k in range(i,n-1):
        print("*",end = " ")
    for l in range(i-1,n-1):
        print("*",end = " ")
    print()
# Out:
#   * * * * * * * * *
#     * * * * * * *
#       * * * * *
#         * * *
#           *

# %%
n = 5
for i in range(n):
    for j in range(i,n-1):
        print(" ",end = ' ')
    for k in range(i+1):
        print("*",end = " ")
    for l in range(i):
        print("*", end = " ") 
    print()
for i in range(1,n):
    for j in range(i):
        print(" ",end =" ")
    for k in range(2*(n - i) - 1):
        print("*",end = " ")
    print()
# Out:
#         *
#       * * *
#     * * * * *
#   * * * * * * *
# * * * * * * * * *
#   * * * * * * *
#     * * * * *
#       * * *
#         *
