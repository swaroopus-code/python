# %%
print("create a complex number and find its conjugate")
z = 3 + 4j
conjugate = z.conjugate()
magnitude = abs(z)
print(f"complex number: {z}")
print(f"comjugate: {conjugate}")
print(f"magnitude: {magnitude}")
# Out:
# create a complex number and find its conjugate
# complex number: (3+4j)
# comjugate: (3-4j)
# magnitude: 5.0

# %%
# Question 1: Create complex number 5 + 3j
z = 5 + 3j
print(f"the complex number is : {z}")
# Out:
# the complex number is : (5+3j)

# %%
real_part = 5
imag_part = 3
z = complex(real_part, imag_part)
print(z)
# Out:
# (5+3j)

# %%
# Question 2: Find the real part of complex number 7 - 2j
z = 7 - 2j
real_part = z.real
print(f"the real part is: {real_part}")
#z.real: This attribute returns the real component of the complex number as a float.
# Out:
# the real part is: 7.0

# %%
# Question 3: Find the imaginary part of complex number 4 + 6j
z = 4 + 6j
imag_part = z.imag
print(f"the imaginary part is: {imag_part}")
# Out:
# the imaginary part is: 6.0

# %%
# Question 4: Add two complex numbers: (3 + 2j) and (1 + 4j)
z1 = 3 +2j
z2 = 1 + 4j
add_complex = z1 +z2
add_complex
# Out:
# (4+6j)

# %%
# Question 5: Multiply two complex numbers: (2 + 3j) and (1 + 2j)
z1 = 2 +3j
z2 = 1 + 2j
mul = z1*z2
mul
# Out:
# (-4+7j)

# %%
# Question 6: Find the magnitude of complex number 6 + 8j
z = 6 +8j
magnitude = abs(z)
magnitude
# Out:
# 10.0

# %%
# Question 7: Find the conjugate of complex number 5 - 7j
z = 5 - 7j
conjugate = z.conjugate()
conjugate
# Out:
# (5+7j)

# %%
# Question 8: Subtract complex numbers: (10 + 5j) - (3 + 2j)
z1 = 10 + 5j
z2 = 3 + 2j
sub = z1 -z2
sub
# Out:
# (7+3j)

# %%
# Question 9: Divide complex numbers: (8 + 6j) / (2 + 1j)
z1 = 8 + 6j
z2 = 2 + 1j
div = z1 / z2
div
# Out:
# (4.4+0.8j)

# %%
# Question 10: Find the phase angle of complex number 1 + 1j
import cmath
z = 1 + 1j
phase_angle = cmath.phase(z)
phase_angle
# Out:
# 0.7853981633974483
