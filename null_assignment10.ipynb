# %%
print("check is variable is none")
variable = None
is_none = variable is None
print(f"variable: {variable}")
print(f"is none: {is_none}")
# Out:
# check is variable is none
# variable: None
# is none: True

# %%
# Question 1: Create a variable and assign None to it
a = None
print(f"the assigneed value of a is : {a}")
# Out:
# the assigneed value of a is : None

# %%
# Question 2: Check if None equals None
a = None
check_a = a is None
print(f"a is None: {check_a}")
# Out:
# a is None: True

# %%
# Question 3: Check if None is None
a = None
b = None
print(a is b)
# Out:
# True

# %%
# Question 4: Check if 0 is None
a = 0
b = None
print( a is b)
# Out:
# False

# %%
# Question 5: Check if empty string is None
a = ""
print(a is None)
# Out:
# False

# %%
# Question 6: Check if False is None
a = False
print(a is None)
# Out:
# False

# %%
# Question 7: Check if empty list is None
a = []
print(a is None)
# Out:
# False

# %%
# Question 8: Check if empty dictionary is None
a = {}
print(a is None)
# Out:
# False

# %%
# Question 9: Check if empty tuple is None
a = ()
print(a is None)
# Out:
# False

# %%
# Question 10: Check if empty set is None
a = set()
print(a is None)

# %% [markdown]
# | Type       | Code      | Is it None? |
# | :---       | :---      | :---        |
# | Integer    | `0`       | False       |
# | Boolean    | `False`   | False       |
# | String     | `""`      | False       |
# | List       | `[]`      | False       |
# | Tuple      | `()`      | False       |
# | Dictionary | `{}`      | False       |
# | Set        | `set()`   | False       |
